# %% [markdown]
# Ejercicio 2:

# %% [markdown]
# Script 1: Grabación del dataset (record-dataset.py)
# Usar la cámara web para capturar imágenes de la mano.
# Utilizar MediaPipe para detectar los landmarks de la mano (21 puntos clave con coordenadas x y y).
# Almacenar las coordenadas de los landmarks junto con la etiqueta correspondiente (0 para "piedra", 1 para "papel", 2 para "tijeras") en archivos .npy (por ejemplo, rps_dataset.npy y rps_labels.npy).

# %%
import cv2
import numpy as np
import mediapipe as mp
import os

# %%
# Inicializamos Mediapipe Hands
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

hands = mp_hands.Hands(static_image_mode=False, max_num_hands=1, min_detection_confidence=0.7)

# %%
# Cargamos datasets si existen
try:
    rps_dataset = list(np.load('rps_dataset.npy', allow_pickle=True))
    rps_labels = list(np.load('rps_labels.npy', allow_pickle=True))
    print("Dataset cargado exitosamente.")
except FileNotFoundError:
    print("No se encontró un dataset existente. Se creará uno nuevo.")
    rps_dataset = []
    rps_labels = []
# Out:
# Dataset cargado exitosamente.

# %%
# Definimos la carpeta de destino
save_dir = r'C:\\Users\\valen\\Downloads\\Parte 2 TP'

# Creamos subcarpetas para cada clase si no existen
gestures = ['piedra', 'papel', 'tijeras']
for gesture in gestures:
    os.makedirs(os.path.join(save_dir, gesture), exist_ok=True)

# %%
# Función para capturar gestos
def capture_gestures():
    cap = cv2.VideoCapture(0)
    labels = {0: 'piedra', 1: 'papel', 2: 'tijeras'}
    
    while cap.isOpened():
        print("Capturando gestos. Presiona 'q' para tomar una foto de cada gesto (piedra, papel, tijeras), y 'p' para detener.")
        
        for label, gesture_name in labels.items():
            print(f"Preparado para capturar gesto {gesture_name}. Presiona 'q' para tomar una foto.")
            
            while True:
                ret, frame = cap.read()
                if not ret:
                    break
                
                rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                result = hands.process(rgb_frame)
                
                if result.multi_hand_landmarks:
                    for hand_landmarks in result.multi_hand_landmarks:
                        mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
                        
                        # Obtenemos coordenadas de los landmarks de la mano
                        landmarks = []
                        for lm in hand_landmarks.landmark:
                            landmarks.append([lm.x, lm.y])
                
                # Mostramos la captura
                cv2.imshow('Hand Gesture Capture', frame)
                
                # Presionando "q" se captura el gesto
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    if result.multi_hand_landmarks:
                        # Guardamos la imagen del gesto en la carpeta específica
                        img_name = f"{gesture_name}_{len(os.listdir(os.path.join(save_dir, gesture_name)))}.png"
                        save_path = os.path.join(save_dir, gesture_name, img_name)
                        cv2.imwrite(save_path, frame)

                        rps_dataset.append(landmarks)
                        rps_labels.append(label)
                        print(f"Foto del gesto {gesture_name} capturada y guardada en {save_path}.")
                    break
                
                # Presionando "p" se detiene el proceso de captura
                if cv2.waitKey(10) & 0xFF == ord('p'):
                    cap.release()
                    cv2.destroyAllWindows()
                    return
    
    cap.release()
    cv2.destroyAllWindows()

# %%
# Ejecutamos el ciclo de captura
capture_gestures()

# Guardamos el dataset actualizado
np.save('rps_dataset.npy', np.array(rps_dataset))
np.save('rps_labels.npy', np.array(rps_labels))
print("Dataset actualizado y guardado exitosamente.")
# Out:
# Capturando gestos. Presiona 'q' para tomar una foto de cada gesto (piedra, papel, tijeras), y 'p' para detener.
# Preparado para capturar gesto piedra. Presiona 'q' para tomar una foto.
# Dataset actualizado y guardado exitosamente.

# %% [markdown]
# Script 2
# Entrenamos un modelo con el dataset generado para predecir si en una imagen se ve piedra, papel o tijera.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# Cargamos los datos del dataset
rps_dataset = np.load('rps_dataset.npy', allow_pickle=True)
rps_labels = np.load('rps_labels.npy', allow_pickle=True)

# Convertimos la lista de landmarks en un array NumPy y ajustar el tamaño adecuado
rps_dataset = np.array(rps_dataset)
rps_dataset = rps_dataset.reshape(rps_dataset.shape[0], 42)  # 21 puntos clave (x, y) = 42 entradas

# Normalizamos los datos
rps_dataset = rps_dataset / np.max(rps_dataset)

# Convertimos etiquetas a formato one-hot encoding
label_binarizer = LabelBinarizer()
rps_labels = label_binarizer.fit_transform(rps_labels)

# Dividimos los datos en conjunto de entrenamiento y validación
X_train, X_val, y_train, y_val = train_test_split(rps_dataset, rps_labels, test_size=0.2, random_state=42)

# Creamos el modelo de la red neuronal con capas densas
model = Sequential([
    Dense(64, activation='relu', input_shape=(42,)),  # 42 entradas (21 puntos clave x, y)
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')  # 3 salidas (piedra, papel, tijeras)
])
# Out:
# c:\Users\valen\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compilamos el modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', tf.keras.metrics.Recall(name='recall')])

# Entrenamos el modelo
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))

# Guardamos el modelo entrenado
model.save('rps_model.h5')

print("Modelo entrenado y guardado como rps_model.h5")
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 279ms/step - accuracy: 0.3564 - loss: 1.0874 - recall: 0.0000e+00 - val_accuracy: 0.3000 - val_loss: 1.0976 - val_recall: 0.0000e+00
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3773 - loss: 1.0503 - recall: 0.0000e+00 - val_accuracy: 0.3000 - val_loss: 1.0970 - val_recall: 0.0000e+00
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3877 - loss: 1.0276 - recall: 0.0000e+00 - val_accuracy: 0.3000 - val_loss: 1.0725 - val_recall: 0.0000e+00
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3668 - loss: 1.0140 - recall: 0.0000e+00 - val_accuracy: 0.3000 - val_loss: 1.0422 - val_recall: 0.0000e+00
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6692 - loss: 0.9928 - recall: 0.0000e+00 - val_accuracy: 0.4000 - val_loss: 1.0269 - val_recall: 0.0000e+00
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6692 - loss: 0.9703 - recall: 0.0000e+00 - val_accuracy: 0.4000 - val_loss: 1.0167 - val_recall: 0.0000e+00
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6796 - loss: 0.9529 - recall: 0.0284 - val_accuracy: 0.6000 - val_loss: 0.9997 - val_recall: 0.1000
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7829 - loss: 0.9300 - recall: 0.0749 - val_accuracy: 0.6000 - val_loss: 0.9806 - val_recall: 0.1000
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7545 - loss: 0.9074 - recall: 0.0853 - val_accuracy: 0.7000 - val_loss: 0.9688 - val_recall: 0.1000
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7441 - loss: 0.8838 - recall: 0.1602 - val_accuracy: 0.5000 - val_loss: 0.9667 - val_recall: 0.2000
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7081 - loss: 0.8596 - recall: 0.2351 - val_accuracy: 0.5000 - val_loss: 0.9706 - val_recall: 0.2000
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6976 - loss: 0.8403 - recall: 0.4057 - val_accuracy: 0.5000 - val_loss: 0.9675 - val_recall: 0.4000
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6976 - loss: 0.8292 - recall: 0.4702 - val_accuracy: 0.5000 - val_loss: 0.9593 - val_recall: 0.4000
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7081 - loss: 0.7952 - recall: 0.5014 - val_accuracy: 0.5000 - val_loss: 0.9343 - val_recall: 0.4000
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6976 - loss: 0.7754 - recall: 0.5659 - val_accuracy: 0.5000 - val_loss: 0.8941 - val_recall: 0.4000
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7469 - loss: 0.7290 - recall: 0.5763 - val_accuracy: 0.7000 - val_loss: 0.8551 - val_recall: 0.4000
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8010 - loss: 0.7209 - recall: 0.5270 - val_accuracy: 0.8000 - val_loss: 0.8242 - val_recall: 0.4000
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8398 - loss: 0.6920 - recall: 0.5583 - val_accuracy: 0.8000 - val_loss: 0.8068 - val_recall: 0.4000
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8218 - loss: 0.6657 - recall: 0.6047 - val_accuracy: 0.7000 - val_loss: 0.8061 - val_recall: 0.4000
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8010 - loss: 0.6533 - recall: 0.6123 - val_accuracy: 0.6000 - val_loss: 0.8385 - val_recall: 0.4000
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7157 - loss: 0.6466 - recall: 0.5270 - val_accuracy: 0.4000 - val_loss: 0.8755 - val_recall: 0.4000
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6796 - loss: 0.6416 - recall: 0.5479 - val_accuracy: 0.5000 - val_loss: 0.8257 - val_recall: 0.4000
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7829 - loss: 0.6041 - recall: 0.6227 - val_accuracy: 0.8000 - val_loss: 0.7597 - val_recall: 0.4000
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8114 - loss: 0.5511 - recall: 0.7261 - val_accuracy: 0.8000 - val_loss: 0.7312 - val_recall: 0.7000
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8682 - loss: 0.5408 - recall: 0.8114 - val_accuracy: 0.9000 - val_loss: 0.7233 - val_recall: 0.7000
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8578 - loss: 0.5363 - recall: 0.8114 - val_accuracy: 0.9000 - val_loss: 0.7122 - val_recall: 0.7000
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8967 - loss: 0.4950 - recall: 0.8114 - val_accuracy: 0.8000 - val_loss: 0.7093 - val_recall: 0.8000
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8682 - loss: 0.4632 - recall: 0.7934 - val_accuracy: 0.8000 - val_loss: 0.7247 - val_recall: 0.7000
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8398 - loss: 0.4600 - recall: 0.8218 - val_accuracy: 0.7000 - val_loss: 0.7485 - val_recall: 0.7000
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8682 - loss: 0.4657 - recall: 0.7829 - val_accuracy: 0.7000 - val_loss: 0.7450 - val_recall: 0.7000
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8578 - loss: 0.4635 - recall: 0.8294 - val_accuracy: 0.8000 - val_loss: 0.7110 - val_recall: 0.7000
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8578 - loss: 0.4236 - recall: 0.8294 - val_accuracy: 0.8000 - val_loss: 0.6903 - val_recall: 0.7000
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8398 - loss: 0.4002 - recall: 0.8114 - val_accuracy: 0.8000 - val_loss: 0.6805 - val_recall: 0.7000
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8114 - loss: 0.3945 - recall: 0.7829 - val_accuracy: 0.8000 - val_loss: 0.6534 - val_recall: 0.8000
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8578 - loss: 0.3881 - recall: 0.8294 - val_accuracy: 0.9000 - val_loss: 0.6493 - val_recall: 0.8000
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8863 - loss: 0.3682 - recall: 0.8863 - val_accuracy: 0.9000 - val_loss: 0.6512 - val_recall: 0.8000
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9251 - loss: 0.3462 - recall: 0.8967 - val_accuracy: 0.9000 - val_loss: 0.6477 - val_recall: 0.8000
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9147 - loss: 0.3393 - recall: 0.8863 - val_accuracy: 0.8000 - val_loss: 0.6573 - val_recall: 0.8000
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8578 - loss: 0.3283 - recall: 0.8294 - val_accuracy: 0.8000 - val_loss: 0.6820 - val_recall: 0.8000
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8682 - loss: 0.3186 - recall: 0.8398 - val_accuracy: 0.7000 - val_loss: 0.7281 - val_recall: 0.7000
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8578 - loss: 0.3393 - recall: 0.8294 - val_accuracy: 0.7000 - val_loss: 0.7543 - val_recall: 0.7000
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8682 - loss: 0.3375 - recall: 0.8398 - val_accuracy: 0.7000 - val_loss: 0.7150 - val_recall: 0.7000
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8578 - loss: 0.3191 - recall: 0.8294 - val_accuracy: 0.8000 - val_loss: 0.6738 - val_recall: 0.8000
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8578 - loss: 0.2919 - recall: 0.8578 - val_accuracy: 0.9000 - val_loss: 0.6557 - val_recall: 0.8000
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9251 - loss: 0.2689 - recall: 0.8967 - val_accuracy: 0.9000 - val_loss: 0.6478 - val_recall: 0.8000
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9147 - loss: 0.2762 - recall: 0.9147 - val_accuracy: 0.8000 - val_loss: 0.6564 - val_recall: 0.8000
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8967 - loss: 0.2523 - recall: 0.8967 - val_accuracy: 0.8000 - val_loss: 0.6887 - val_recall: 0.8000
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8787 - loss: 0.2579 - recall: 0.8787 - val_accuracy: 0.8000 - val_loss: 0.7105 - val_recall: 0.8000
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8863 - loss: 0.2665 - recall: 0.8863 - val_accuracy: 0.9000 - val_loss: 0.7043 - val_recall: 0.8000
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9147 - loss: 0.2622 - recall: 0.9147 - val_accuracy: 0.9000 - val_loss: 0.6961 - val_recall: 0.9000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Modelo entrenado y guardado como rps_model.h5

# %% [markdown]
# Script 3
#
# Utilizando el modelo predecimos en tiempo real los gestos que haga una mano.

# %%
import cv2
import numpy as np
import mediapipe as mp
from tensorflow.keras.models import load_model

# Inicializamos MediaPipe Hands
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
hands = mp_hands.Hands(static_image_mode=False, max_num_hands=1, min_detection_confidence=0.7)

# Cargamos el modelo entrenado
model = load_model('rps_model.h5')

# Etiquetas de los gestos
gestures = ["Piedra", "Papel", "Tijeras"]

# Captura de la cámara
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Convertimos la imagen a RGB
    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image_rgb.flags.writeable = False

    # Detección de los landmarks de la mano
    results = hands.process(image_rgb)

    image_rgb.flags.writeable = True
    image_bgr = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Extraemos las coordenadas x e y de los landmarks
            landmarks = []
            for landmark in hand_landmarks.landmark:
                landmarks.append(landmark.x)
                landmarks.append(landmark.y)
            
            # Convertimos a formato numpy array y hacemos la predicción
            landmarks = np.array(landmarks).reshape(1, -1)
            prediction = model.predict(landmarks)
            gesture = gestures[np.argmax(prediction)]

            # Dibujamos los landmarks en la imagen
            mp_drawing.draw_landmarks(image_bgr, hand_landmarks, mp_hands.HAND_CONNECTIONS)

            # Mostramos el gesto reconocido en pantalla
            cv2.putText(image_bgr, f'Gesto: {gesture}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

    # Mostramos la imagen en pantalla
    cv2.imshow('Piedra, Papel o Tijeras', image_bgr)

    # Salimos del bucle si se presiona la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar los recursos
cap.release()
cv2.destroyAllWindows()
hands.close()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %% [markdown]
# Conclusion
#
# En este ejercicio creamos satisfactoriamente un script que nos permitio generar rapidamente un dataset modesto con imagenes de piedra, papel o tijera, para luego entrenar un modelo con ese dataset que finalmente utilizamos para predecir en tiempo real que gesto esta haciendo una mano y escribir en pantalla la prediccion.
# Al ser una tarea sencilla para alcanzar una muy buena accuracy no hizo falta utilizar un modelo complejo, se utilizaron capas densas.
